# %%
import flwr as fl

# %%
fl.server.start_server(
    server_address="0.0.0.0:8080",
    config=fl.server.ServerConfig(num_rounds=3),
    strategy=fl.server.strategy.FedAvg()
)
# Out:
# INFO flwr 2025-03-16 16:00:19,564 | app.py:139 | Starting Flower server, config: ServerConfig(num_rounds=3, round_timeout=None)
# INFO flwr 2025-03-16 16:00:19,587 | app.py:152 | Flower ECE: gRPC server running (3 rounds), SSL is disabled
# INFO flwr 2025-03-16 16:00:19,590 | server.py:86 | Initializing global parameters
# INFO flwr 2025-03-16 16:00:19,642 | server.py:270 | Requesting initial parameters from one random client
# INFO flwr 2025-03-16 16:01:30,428 | server.py:274 | Received initial parameters from one random client
# INFO flwr 2025-03-16 16:01:30,429 | server.py:88 | Evaluating initial parameters
# INFO flwr 2025-03-16 16:01:30,430 | server.py:101 | FL starting
# DEBUG flwr 2025-03-16 16:03:19,335 | server.py:215 | fit_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-03-16 16:03:20,558 | server.py:229 | fit_round 1 received 2 results and 0 failures
# WARNING flwr 2025-03-16 16:03:20,562 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2025-03-16 16:03:20,562 | server.py:165 | evaluate_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-03-16 16:03:24,706 | server.py:179 | evaluate_round 1 received 2 results and 0 failures
# WARNING flwr 2025-03-16 16:03:24,706 | fedavg.py:273 | No evaluate_metrics_aggregation_fn provided
# DEBUG flwr 2025-03-16 16:03:24,707 | server.py:215 | fit_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-03-16 16:03:25,580 | server.py:229 | fit_round 2 received 2 results and 0 failures
# DEBUG flwr 2025-03-16 16:03:25,583 | server.py:165 | evaluate_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-03-16 16:03:29,289 | server.py:179 | evaluate_round 2 received 2 results and 0 failures
# DEBUG flwr 2025-03-16 16:03:29,290 | server.py:215 | fit_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-03-16 16:03:30,172 | server.py:229 | fit_round 3 received 2 results and 0 failures
# DEBUG flwr 2025-03-16 16:03:30,176 | server.py:165 | evaluate_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-03-16 16:03:33,845 | server.py:179 | evaluate_round 3 received 2 results and 0 failures
# INFO flwr 2025-03-16 16:03:33,846 | server.py:144 | FL finished in 123.41587683599937
# INFO flwr 2025-03-16 16:03:33,846 | app.py:202 | app_fit: losses_distributed [(1, 2869.4189453125), (2, 2823.0673828125), (3, 2688.529541015625)]
# INFO flwr 2025-03-16 16:03:33,847 | app.py:203 | app_fit: metrics_distributed {}
# INFO flwr 2025-03-16 16:03:33,847 | app.py:204 | app_fit: losses_centralized []
# INFO flwr 2025-03-16 16:03:33,848 | app.py:205 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 2869.4189453125
# 	round 2: 2823.0673828125
# 	round 3: 2688.529541015625
