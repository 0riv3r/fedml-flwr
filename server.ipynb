# %%
import flwr as fl

# %%
fl.server.start_server(
    server_address="0.0.0.0:8080",
    config=fl.server.ServerConfig(num_rounds=3),
    strategy=fl.server.strategy.FedAvg()
)
# Out:
# INFO flwr 2025-05-10 15:05:18,962 | app.py:139 | Starting Flower server, config: ServerConfig(num_rounds=3, round_timeout=None)
# INFO flwr 2025-05-10 15:05:19,023 | app.py:152 | Flower ECE: gRPC server running (3 rounds), SSL is disabled
# INFO flwr 2025-05-10 15:05:19,024 | server.py:86 | Initializing global parameters
# INFO flwr 2025-05-10 15:05:19,025 | server.py:270 | Requesting initial parameters from one random client
# INFO flwr 2025-05-10 15:07:00,398 | server.py:274 | Received initial parameters from one random client
# INFO flwr 2025-05-10 15:07:00,489 | server.py:88 | Evaluating initial parameters
# INFO flwr 2025-05-10 15:07:00,493 | server.py:101 | FL starting
# DEBUG flwr 2025-05-10 15:07:21,833 | server.py:215 | fit_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-05-10 15:07:33,486 | server.py:229 | fit_round 1 received 2 results and 0 failures
# WARNING flwr 2025-05-10 15:07:33,540 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2025-05-10 15:07:33,542 | server.py:165 | evaluate_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2025-05-10 15:07:51,891 | server.py:179 | evaluate_round 1 received 2 results and 0 failures
# WARNING flwr 2025-05-10 15:07:51,893 | fedavg.py:273 | No evaluate_metrics_aggregation_fn provided
# DEBUG flwr 2025-05-10 15:07:51,894 | server.py:215 | fit_round 2: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2025-05-10 15:08:07,578 | server.py:229 | fit_round 2 received 3 results and 0 failures
# DEBUG flwr 2025-05-10 15:08:07,589 | server.py:165 | evaluate_round 2: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2025-05-10 15:08:27,165 | server.py:179 | evaluate_round 2 received 3 results and 0 failures
# DEBUG flwr 2025-05-10 15:08:27,166 | server.py:215 | fit_round 3: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2025-05-10 15:08:42,722 | server.py:229 | fit_round 3 received 3 results and 0 failures
# DEBUG flwr 2025-05-10 15:08:42,726 | server.py:165 | evaluate_round 3: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2025-05-10 15:09:06,751 | server.py:179 | evaluate_round 3 received 3 results and 0 failures
# INFO flwr 2025-05-10 15:09:06,753 | server.py:144 | FL finished in 126.25739120999788
# INFO flwr 2025-05-10 15:09:06,767 | app.py:202 | app_fit: losses_distributed [(1, 2452.740966796875), (2, 2136.64453125), (3, 1955.985107421875)]
# INFO flwr 2025-05-10 15:09:06,769 | app.py:203 | app_fit: metrics_distributed {}
# INFO flwr 2025-05-10 15:09:06,770 | app.py:204 | app_fit: losses_centralized []
# INFO flwr 2025-05-10 15:09:06,771 | app.py:205 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 2452.740966796875
# 	round 2: 2136.64453125
# 	round 3: 1955.985107421875
